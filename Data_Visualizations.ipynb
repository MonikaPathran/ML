# %% [markdown]
# <a href="https://colab.research.google.com/github/MonikaPathran/MachineLearning/blob/main/Data_Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import pandas as pd
import numpy as np

# %%
# Data used for each type of plots
data_plot = pd.DataFrame(np.random.randn(10, 4),
                  index=pd.date_range('1/1/2000', periods=10),
                  columns=['Amazon', 'Apple', 'Meta', 'Alphabet'])

# # For bar plot
data_bar = pd.DataFrame(np.random.randint(low=2, high=100, size=(10,4)),columns=['Amazon', 'Apple', 'Meta', 'Alphabet'])


# # For histogram
data_hist = pd.DataFrame({'Maths':np.random.randint(low=30, high=100, size=100),
                         'Science':np.random.randint(low=10, high=80, size=100),
                         'Language':np.random.randint(low=40, high=70, size=100)},
                         columns=['Maths', 'Science', 'Language'])

# # For box plot
data_box = pd.DataFrame(np.random.rand(10, 5), columns=['ME', 'ECE', 'EE', 'IT', 'CS'])

# # For area plot
data_area = pd.DataFrame(np.random.rand(10, 4), columns=['Chennai', 'Bangalore', 'Coimbatore', 'Pune'])

# # For scatter plot
data_scatter = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])

# # For pie chart
data_pie = pd.DataFrame(3 * np.random.rand(5), index=['Rent', 'Grocery', 'Outing', 'EMI', 'Misc'], columns=['Expenses'])

data_plot
# Out:
#               Amazon     Apple      Meta  Alphabet
# 2000-01-01 -0.824964  1.387381 -0.319419  0.391290
# 2000-01-02  1.047886 -0.242034 -0.528951  0.868387
# 2000-01-03  0.621702  0.175960  0.102205 -1.583540
# 2000-01-04  0.472255 -0.817973  0.957037  0.243346
# 2000-01-05  1.033991 -0.108353  1.932253 -0.900986
# 2000-01-06  0.392334 -0.209604 -0.961759 -1.166354
# 2000-01-07  0.651080  0.760957 -0.139394  0.483381
# 2000-01-08  0.394541 -1.331244 -0.841365 -1.562746
# 2000-01-09 -0.409402 -0.462095 -0.086445  1.739930
# 2000-01-10 -0.256004  1.303499 -0.978301  0.450308

# %% [markdown]
# ### Plot

# %%
# Look at the dataframe
# Stock prize rate for 10 days
data_plot
# Out:
#               Amazon     Apple      Meta  Alphabet
# 2000-01-01  0.852606 -0.148031 -0.766283 -0.085184
# 2000-01-02 -0.070898  0.044173  1.099914  0.120755
# 2000-01-03  0.722900  0.690787  0.796579  0.412103
# 2000-01-04 -0.885729 -0.123530 -0.072119  1.465723
# 2000-01-05  0.609567 -1.070271 -0.868603  0.763897
# 2000-01-06  0.140192 -1.219978  1.412166  0.242331
# 2000-01-07  0.453290  1.261118 -1.717603  0.185072
# 2000-01-08  0.139693  0.091657 -0.801778  0.300155
# 2000-01-09 -1.548055  1.094099 -0.180687 -1.107415
# 2000-01-10  0.689727  1.876412 -0.574190  1.203882

# %%
# Plot
data_plot.plot()
# Out:
# <Axes: >

# %%
data_plot.plot?

# %% [markdown]
# ### Bar

# %%
# Look at the dataframe
# How many shares got sold in a day
data_bar
# Out:
#    Amazon  Apple  Meta  Alphabet
# 0      37     77    39         8
# 1      94     84    40         4
# 2      78     36    85        42
# 3      92     83    52        39
# 4      87     49    48        29
# 5      69     51    98        32
# 6      19     58    35        59
# 7      21     64    14         3
# 8      84     49    10        30
# 9      75     73    87        50

# %%
# Bar plot
data_bar.plot.bar()
# Out:
# <Axes: >

# %%
# Alternative
data_bar.plot(kind='bar',
              title='No. of shares sold in a day',
              xlabel='Days',
              ylabel='No. of shares')
# Out:
# <Axes: title={'center': 'No. of shares sold in a day'}, xlabel='Days', ylabel='No. of shares'>

# %%
# Bar plot - stacked
data_bar.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
# Barh plot
data_bar.plot.barh()
# Out:
# <Axes: >

# %%
# Barh plot - Stacked
data_bar.plot.barh(stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Histogram plot

# %%
# Visualize the dataframe
# Marks of students in a class
data_hist
# Out:
#     Maths  Science  Language
# 0      31       74        55
# 1      91       17        42
# 2      71       62        58
# 3      68       62        51
# 4      45       34        53
# ..    ...      ...       ...
# 95     30       64        53
# 96     81       58        58
# 97     60       58        64
# 98     91       48        56
# 99     81       44        41
#
# [100 rows x 3 columns]

# %%
# Histogram plot
data_hist.hist()
# Out:
# array([[<Axes: title={'center': 'Maths'}>,
#         <Axes: title={'center': 'Science'}>],
#        [<Axes: title={'center': 'Language'}>, <Axes: >]], dtype=object)

# %%
# Mark distribution for Maths
data_hist.Maths.plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data_hist.plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### KDE plot

# %%
# Distribution of data
data_hist.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### Box plot

# %%
# Look at the dataframe
# Placement percentage of departments in college
data_box.head()
# Out:
#          ME       ECE        EE        IT        CS
# 0  0.123442  0.320747  0.105841  0.707763  0.799924
# 1  0.151181  0.466336  0.972839  0.615569  0.026270
# 2  0.689840  0.316406  0.611236  0.251835  0.520609
# 3  0.179785  0.697473  0.885330  0.351182  0.691802
# 4  0.171288  0.384838  0.335740  0.923456  0.428369

# %%
# Box plot
data_box.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# ### Area plot

# %%
# Look at the dataframe
# Percentage of people migrating to the city
data_area
# Out:
#     Chennai  Bangalore  Coimbatore      Pune
# 0  0.184244   0.819924    0.157399  0.874841
# 1  0.333435   0.945873    0.433642  0.375935
# 2  0.524725   0.958968    0.123500  0.312216
# 3  0.100840   0.435953    0.223871  0.985099
# 4  0.791673   0.048553    0.475559  0.937516
# 5  0.982531   0.365039    0.484205  0.298343
# 6  0.656872   0.904553    0.798683  0.194772
# 7  0.878282   0.632313    0.994734  0.157299
# 8  0.049399   0.577819    0.597741  0.956672
# 9  0.738996   0.391617    0.899279  0.708859

# %%
# Area plot
data_area.plot.area()
# Out:
# <Axes: >

# %% [markdown]
# ### Scatter plot

# %%
# Look at the data
# Visualizing the clustered documents
data_scatter.head()
# Out:
#           a         b         c         d
# 0  0.132826  0.858774  0.373237  0.693567
# 1  0.209143  0.071089  0.930902  0.615612
# 2  0.714239  0.574423  0.711889  0.052235
# 3  0.800828  0.275595  0.401986  0.792634
# 4  0.719521  0.635498  0.445707  0.791065

# %%
# Plot scatter plot
data_scatter.plot.scatter(x='a', y='b', color = ['blue'])
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# ### Pie plot

# %%
# Look at the data
# Track expenses
data_pie
# Out:
#          Expenses
# Rent     2.990329
# Grocery  0.865539
# Outing   1.369187
# EMI      0.069462
# Misc     2.473065

# %%
data_pie
# Out:
#          Expenses
# Rent     1.557387
# Grocery  0.606149
# Outing   1.120704
# EMI      1.162093
# Misc     1.084739

# %%
# Create pie-chart
data_pie.plot.pie(subplots=True)
# Out:
# array([<Axes: ylabel='Expenses'>], dtype=object)
